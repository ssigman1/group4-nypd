# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd

# %% [markdown]
# ### IGNORED, DISMISSED: How the NYPD Neglects 311 Complaints about Driver Misconduct
#
# 1. Go to the New Data Portal: https://opendata.cityofnewyork.us/
# 2. Find each dataset. 311 requests and police precinct
# 3. Add a data notes section to your github readme. This should include information about the source of your data, where it came from, how often it is updated, and the period of data it contains (e.g. 2010-present or 2012 to 2019)
# 4. Lastly, test that this import works. This may take a while as the dataset is large.

# %%
# query NYC 311 for driver misconduct
# value list
complaint_types_dm = ('Blocked Bike Lane', 'Blocked Crosswalk', 'Blocked Hydrant', 'Blocked Sidewalk', 'Chronic Speeding', 'Chronic Stoplight Violation','Detached Trailer', 'Double Parked Blocking Traffic',
       'Double Parked Blocking Vehicle', 'Drag Racing',
       'Overnight Commercial Storage', 'Parking Permit Improper Use',
       'Posted Parking Sign Violation', 'Truck Route Violation',
       'Unauthorized Bus Layover', 'Abandoned Vehicle With License Plate' )
query = "https://data.cityofnewyork.us/resource/erm2-nwe9.csv?$query=" +  requests.utils.quote(f"SELECT * WHERE descriptor IN {complaint_types_dm}  LIMIT 3000000")
dm  = pd.read_csv(query)
# Out:
# <ipython-input-24-c56bcde3c9d2>:9: DtypeWarning: Columns (15,18,20,31,34,35,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   dm  = pd.read_csv(query)

# %%
dm.shape
# Out:
# (2201253, 41)

# %%
dm.head()
# Out:
#    unique_key             created_date closed_date agency  \
# 0    60938395  2024-04-22T01:47:11.000         NaN   NYPD
# 1    60940393  2024-04-22T01:39:06.000         NaN   NYPD
# 2    60941348  2024-04-22T01:38:46.000         NaN   NYPD
# 3    60936410  2024-04-22T01:38:28.000         NaN   NYPD
# 4    60936416  2024-04-22T01:29:01.000         NaN   NYPD
#
#                        agency_name   complaint_type  \
# 0  New York City Police Department  Illegal Parking
# 1  New York City Police Department  Illegal Parking
# 2  New York City Police Department  Illegal Parking
# 3  New York City Police Department  Illegal Parking
# 4  New York City Police Department  Illegal Parking
#
#                        descriptor    location_type  incident_zip  \
# 0   Posted Parking Sign Violation  Street/Sidewalk       11235.0
# 1  Double Parked Blocking Traffic  Street/Sidewalk       11212.0
# 2                 Blocked Hydrant  Street/Sidewalk       11373.0
# 3                 Blocked Hydrant  Street/Sidewalk       11214.0
# 4  Double Parked Blocking Traffic  Street/Sidewalk       11214.0
#
#         incident_address  ... vehicle_type taxi_company_borough  \
# 0  302 OCEAN VIEW AVENUE  ...          NaN                  NaN
# 1     612 CHESTER STREET  ...          Car                  NaN
# 2        92-17 54 AVENUE  ...          NaN                  NaN
# 3         2069 85 STREET  ...          NaN                  NaN
# 4         8810 24 AVENUE  ...          Car                  NaN
#
#   taxi_pick_up_location bridge_highway_name bridge_highway_direction  \
# 0                   NaN                 NaN                      NaN
# 1                   NaN                 NaN                      NaN
# 2                   NaN                 NaN                      NaN
# 3                   NaN                 NaN                      NaN
# 4                   NaN                 NaN                      NaN
#
#   road_ramp bridge_highway_segment   latitude  longitude  \
# 0       NaN                    NaN  40.579012 -73.964786
# 1       NaN                    NaN  40.656565 -73.908366
# 2       NaN                    NaN  40.738106 -73.870321
# 3       NaN                    NaN  40.604371 -73.996226
# 4       NaN                    NaN  40.595027 -73.993810
#
#                                           location
# 0    \n,  \n(40.5790117976162, -73.96478559193572)
# 1   \n,  \n(40.65656499095104, -73.90836564187046)
# 2  \n,  \n(40.738105700370596, -73.87032076493618)
# 3   \n,  \n(40.60437084599537, -73.99622585195348)
# 4   \n,  \n(40.59502745073003, -73.99381025507276)
#
# [5 rows x 41 columns]

# %%
dm.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'location_type', 'incident_zip',
#        'incident_address', 'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'address_type',
#        'city', 'landmark', 'facility_type', 'status', 'due_date',
#        'resolution_description', 'resolution_action_updated_date',
#        'community_board', 'bbl', 'borough', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane', 'open_data_channel_type',
#        'park_facility_name', 'park_borough', 'vehicle_type',
#        'taxi_company_borough', 'taxi_pick_up_location', 'bridge_highway_name',
#        'bridge_highway_direction', 'road_ramp', 'bridge_highway_segment',
#        'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
# get police precint data

police = gpd.read_file('https://data.cityofnewyork.us/api/geospatial/78dh-3ptz?method=export&format=GeoJSON')

# %%
police.columns
# Out:
# Index(['precinct', 'shape_area', 'shape_leng', 'geometry'], dtype='object')

# %%
dm.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'location_type', 'incident_zip',
#        'incident_address', 'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'address_type',
#        'city', 'landmark', 'facility_type', 'status', 'due_date',
#        'resolution_description', 'resolution_action_updated_date',
#        'community_board', 'bbl', 'borough', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane', 'open_data_channel_type',
#        'park_facility_name', 'park_borough', 'vehicle_type',
#        'taxi_company_borough', 'taxi_pick_up_location', 'bridge_highway_name',
#        'bridge_highway_direction', 'road_ramp', 'bridge_highway_segment',
#        'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
dm['created_date'] = pd.to_datetime(dm['created_date'])
dm['closed_date'] = pd.to_datetime(dm['closed_date'])
dm['duration'] = dm['closed_date'] - dm['created_date']

filtered_dm = dm[dm['duration'] <= pd.Timedelta(minutes=5)]

# %%
filtered_dm.sample(8)
# Out:
#          unique_key        created_date         closed_date agency  \
# 1328964    46467362 2020-06-13 22:28:23 2020-06-13 22:31:10   NYPD
# 332886     58197648 2023-07-14 14:41:44 2023-07-14 14:44:04   NYPD
# 1333861    46352853 2020-05-31 20:54:42 2020-05-31 20:56:36   NYPD
# 670417     55351132 2022-09-09 07:06:54 2022-09-09 07:08:29   NYPD
# 1381073    45434778 2020-01-21 09:52:44 2020-01-21 09:55:26   NYPD
# 1219748    48440288 2020-12-18 21:42:31 2020-12-18 21:46:42   NYPD
# 1213388    48541144 2020-12-31 16:07:10 2020-12-31 16:09:48   NYPD
# 619405     55812539 2022-10-26 21:08:28 2022-10-26 21:10:51   NYPD
#
#                              agency_name   complaint_type  \
# 1328964  New York City Police Department  Illegal Parking
# 332886   New York City Police Department  Illegal Parking
# 1333861  New York City Police Department  Illegal Parking
# 670417   New York City Police Department  Illegal Parking
# 1381073  New York City Police Department  Illegal Parking
# 1219748  New York City Police Department  Illegal Parking
# 1213388  New York City Police Department  Illegal Parking
# 619405   New York City Police Department  Illegal Parking
#
#                             descriptor    location_type  incident_zip  \
# 1328964                Blocked Hydrant  Street/Sidewalk       11235.0
# 332886                Blocked Sidewalk  Street/Sidewalk       11101.0
# 1333861                Blocked Hydrant  Street/Sidewalk       11223.0
# 670417                 Blocked Hydrant  Street/Sidewalk       11209.0
# 1381073  Posted Parking Sign Violation              NaN       11204.0
# 1219748                Blocked Hydrant  Street/Sidewalk       11223.0
# 1213388  Posted Parking Sign Violation  Street/Sidewalk       11366.0
# 619405               Blocked Bike Lane  Street/Sidewalk       11216.0
#
#                 incident_address  ... taxi_company_borough  \
# 1328964    2514 EAST   27 STREET  ...                  NaN
# 332886           45-30 23 STREET  ...                  NaN
# 1333861   2146 WEST FIFTH STREET  ...                  NaN
# 670417             543 78 STREET  ...                  NaN
# 1381073           2255 60 STREET  ...                  NaN
# 1219748    2320 WEST   12 STREET  ...                  NaN
# 1213388  78-15 PARSONS BOULEVARD  ...                  NaN
# 619405       333 TOMPKINS AVENUE  ...                  NaN
#
#         taxi_pick_up_location bridge_highway_name bridge_highway_direction  \
# 1328964                   NaN                 NaN                      NaN
# 332886                    NaN                 NaN                      NaN
# 1333861                   NaN                 NaN                      NaN
# 670417                    NaN                 NaN                      NaN
# 1381073                   NaN                 NaN                      NaN
# 1219748                   NaN                 NaN                      NaN
# 1213388                   NaN                 NaN                      NaN
# 619405                    NaN                 NaN                      NaN
#
#         road_ramp bridge_highway_segment   latitude  longitude  \
# 1328964       NaN                    NaN  40.590836 -73.942996
# 332886        NaN                    NaN  40.746156 -73.945563
# 1333861       NaN                    NaN  40.595544 -73.976317
# 670417        NaN                    NaN  40.626607 -74.022487
# 1381073       NaN                    NaN  40.615990 -73.977250
# 1219748       NaN                    NaN  40.590758 -73.982174
# 1213388       NaN                    NaN  40.721959 -73.809697
# 619405        NaN                    NaN  40.686512 -73.944533
#
#                                                 location        duration
# 1328964   \n,  \n(40.59083589355055, -73.94299598753597) 0 days 00:02:47
# 332886   \n,  \n(40.746155817304896, -73.94556258578667) 0 days 00:02:20
# 1333861    \n,  \n(40.5955439440572, -73.97631747077207) 0 days 00:01:54
# 670417    \n,  \n(40.62660702254857, -74.02248671869454) 0 days 00:01:35
# 1381073   \n,  \n(40.61599011709983, -73.97725031621711) 0 days 00:02:42
# 1219748   \n,  \n(40.59075807181942, -73.98217366606649) 0 days 00:04:11
# 1213388   \n,  \n(40.72195913199264, -73.80969682426189) 0 days 00:02:38
# 619405     \n,  \n(40.68651167196951, -73.9445331671365) 0 days 00:02:23
#
# [8 rows x 42 columns]

# %% [markdown]
# Day of week

# %%
data = filtered_dm['created_date'].value_counts()

# %%
def get_day_of_week(date_str):
    date_obj = pd.to_datetime(date_str)
    return date_obj.day_name()

# %%
filtered_dm.loc[:,'day_of_week'] = filtered_dm['created_date'].apply(get_day_of_week)

# %%
day_counts = filtered_dm.groupby('day_of_week').size().reset_index(name='day_count')

# %%
filtered_dm.sample()
# Out:
#         unique_key        created_date         closed_date agency  \
# 108184    60118286 2024-01-23 19:35:10 2024-01-23 19:36:11   NYPD
#
#                             agency_name   complaint_type         descriptor  \
# 108184  New York City Police Department  Illegal Parking  Blocked Bike Lane
#
#           location_type  incident_zip incident_address  ...  \
# 108184  Street/Sidewalk       11215.0     372 3 STREET  ...
#
#        taxi_pick_up_location bridge_highway_name bridge_highway_direction  \
# 108184                   NaN                 NaN                      NaN
#
#        road_ramp bridge_highway_segment   latitude longitude  \
# 108184       NaN                    NaN  40.672572 -73.98284
#
#                                               location        duration  \
# 108184  \n,  \n(40.67257207716305, -73.98284034799634) 0 days 00:01:01
#
#        day_of_week
# 108184     Tuesday
#
# [1 rows x 43 columns]
