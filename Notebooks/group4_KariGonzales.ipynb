# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd

# %% [markdown]
# ### IGNORED, DISMISSED: How the NYPD Neglects 311 Complaints about Driver Misconduct
#
# 1. Go to the New Data Portal: https://opendata.cityofnewyork.us/
# 2. Find each dataset. 311 requests and police precinct
# 3. Add a data notes section to your github readme. This should include information about the source of your data, where it came from, how often it is updated, and the period of data it contains (e.g. 2010-present or 2012 to 2019)
# 4. Lastly, test that this import works. This may take a while as the dataset is large.

# %%
# query NYC 311 for driver misconduct
# value list
complaint_types_dm = ('Blocked Bike Lane', 'Blocked Crosswalk', 'Blocked Hydrant', 'Blocked Sidewalk', 'Chronic Speeding', 'Chronic Stoplight Violation','Detached Trailer', 'Double Parked Blocking Traffic',
       'Double Parked Blocking Vehicle', 'Drag Racing',
       'Overnight Commercial Storage', 'Parking Permit Improper Use',
       'Posted Parking Sign Violation', 'Truck Route Violation',
       'Unauthorized Bus Layover', 'Abandoned Vehicle With License Plate' )
query = "https://data.cityofnewyork.us/resource/erm2-nwe9.csv?$query=" +  requests.utils.quote(f"SELECT * WHERE descriptor IN {complaint_types_dm}  LIMIT 3000000")
dm  = pd.read_csv(query)
# Out:
# <ipython-input-3-c56bcde3c9d2>:9: DtypeWarning: Columns (15,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   dm  = pd.read_csv(query)

# %%
dm.shape
# Out:
# (1353860, 41)

# %%
dm.head()
# Out:
#    unique_key             created_date closed_date agency  \
# 0    60950066  2024-04-23T01:49:34.000         NaN   NYPD
# 1    60946404  2024-04-23T01:43:47.000         NaN   NYPD
# 2    60945024  2024-04-23T01:41:15.000         NaN   NYPD
# 3    60951326  2024-04-23T01:41:03.000         NaN   NYPD
# 4    60950078  2024-04-23T01:36:14.000         NaN   NYPD
#
#                        agency_name   complaint_type  \
# 0  New York City Police Department  Illegal Parking
# 1  New York City Police Department  Illegal Parking
# 2  New York City Police Department  Illegal Parking
# 3  New York City Police Department  Illegal Parking
# 4  New York City Police Department  Illegal Parking
#
#                       descriptor    location_type  incident_zip  \
# 0                Blocked Hydrant  Street/Sidewalk       11368.0
# 1    Parking Permit Improper Use  Street/Sidewalk       11368.0
# 2                Blocked Hydrant  Street/Sidewalk       11356.0
# 3                Blocked Hydrant  Street/Sidewalk       11239.0
# 4  Posted Parking Sign Violation  Street/Sidewalk       10464.0
#
#       incident_address  ... vehicle_type taxi_company_borough  \
# 0     55-20 111 STREET  ...          NaN                  NaN
# 1     34-25 109 STREET  ...          NaN                  NaN
# 2     10-10 116 STREET  ...          NaN                  NaN
# 3  749 VANDALIA AVENUE  ...          NaN                  NaN
# 4     176 CROSS STREET  ...          NaN                  NaN
#
#   taxi_pick_up_location bridge_highway_name bridge_highway_direction  \
# 0                   NaN                 NaN                      NaN
# 1                   NaN                 NaN                      NaN
# 2                   NaN                 NaN                      NaN
# 3                   NaN                 NaN                      NaN
# 4                   NaN                 NaN                      NaN
#
#   road_ramp bridge_highway_segment   latitude  longitude  \
# 0       NaN                    NaN  40.741982 -73.850776
# 1       NaN                    NaN  40.756107 -73.859558
# 2       NaN                    NaN  40.788183 -73.851466
# 3       NaN                    NaN  40.658512 -73.866821
# 4       NaN                    NaN  40.853473 -73.788792
#
#                                           location
# 0  \n,  \n(40.741982330673174, -73.85077556011962)
# 1  \n,  \n(40.756106888048976, -73.85955830379348)
# 2   \n,  \n(40.78818278035146, -73.85146648166618)
# 3    \n,  \n(40.65851161400836, -73.8668208197035)
# 4  \n,  \n(40.853472562055316, -73.78879219451085)
#
# [5 rows x 41 columns]

# %%
dm.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'location_type', 'incident_zip',
#        'incident_address', 'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'address_type',
#        'city', 'landmark', 'facility_type', 'status', 'due_date',
#        'resolution_description', 'resolution_action_updated_date',
#        'community_board', 'bbl', 'borough', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane', 'open_data_channel_type',
#        'park_facility_name', 'park_borough', 'vehicle_type',
#        'taxi_company_borough', 'taxi_pick_up_location', 'bridge_highway_name',
#        'bridge_highway_direction', 'road_ramp', 'bridge_highway_segment',
#        'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
# get police precint data

police = gpd.read_file('https://data.cityofnewyork.us/api/geospatial/78dh-3ptz?method=export&format=GeoJSON')

# %%
police.columns
# Out:
# Index(['precinct', 'shape_area', 'shape_leng', 'geometry'], dtype='object')

# %%
dm.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'location_type', 'incident_zip',
#        'incident_address', 'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'address_type',
#        'city', 'landmark', 'facility_type', 'status', 'due_date',
#        'resolution_description', 'resolution_action_updated_date',
#        'community_board', 'bbl', 'borough', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane', 'open_data_channel_type',
#        'park_facility_name', 'park_borough', 'vehicle_type',
#        'taxi_company_borough', 'taxi_pick_up_location', 'bridge_highway_name',
#        'bridge_highway_direction', 'road_ramp', 'bridge_highway_segment',
#        'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
dm['created_date'] = pd.to_datetime(dm['created_date'])
dm['closed_date'] = pd.to_datetime(dm['closed_date'])
dm['duration'] = dm['closed_date'] - dm['created_date']

dm_filtered = dm[dm['duration'] <= pd.Timedelta(minutes=5)]

# %%
dm_filtered.sample(8)
# Out:
#          unique_key        created_date         closed_date agency  \
# 600071     55983454 2022-11-14 15:55:23 2022-11-14 15:56:30   NYPD
# 1118375    50626172 2021-05-20 17:04:17 2021-05-20 17:05:32   NYPD
# 1285326    47487796 2020-09-06 20:33:07 2020-09-06 20:36:23   NYPD
# 378264     57819085 2023-06-06 19:20:44 2023-06-06 19:22:40   NYPD
# 759417    \n,  \n(40.83855707927812, -73.91388286014495) 0 days 00:03:27
# 522058    \n,  \n(40.80156791710398, -73.94262409319579) 0 days 00:01:22
# 1019129  \n,  \n(40.716593384034745, -73.86183483532683) 0 days 00:03:53
# 254334    \n,  \n(40.79347978401433, -73.97496135909094) 0 days 00:03:44
#
# [8 rows x 42 columns]

# %% [markdown]
# Day of week

# %%
data = dm_filtered['created_date'].value_counts()

# %%
def get_day_of_week(date_str):
    date_obj = pd.to_datetime(date_str)
    return date_obj.day_name()

# %%
dm_filtered.loc[:, 'day_of_week'] = dm_filtered['created_date'].apply(get_day_of_week)

# %%
day_counts = dm_filtered.groupby('day_of_week').size().reset_index(name='day_count')

# %%
dm_filtered.head()
# Out:
#      unique_key        created_date         closed_date agency  \
# 121    60948005 2024-04-22 22:32:09 2024-04-22 22:34:03   NYPD
# 147    60945232 2024-04-22 22:19:56 2024-04-22 22:24:51   NYPD
# 332    60946769 2024-04-22 19:08:44 2024-04-22 19:12:22   NYPD
# 398    60949323 2024-04-22 17:58:11 2024-04-22 18:01:15   NYPD
# 427    60950485 2024-04-22 17:34:46 2024-04-22 17:36:20   NYPD
#
#                          agency_name   complaint_type  \
# 121  New York City Police Department  Illegal Parking
# 147  New York City Police Department  Illegal Parking
# 332  New York City Police Department  Illegal Parking
# 398  New York City Police Department  Illegal Parking
# 427  New York City Police Department  Illegal Parking
#
#                         descriptor    location_type  incident_zip  \
# 121   Overnight Commercial Storage  Street/Sidewalk       10024.0
# 147              Blocked Crosswalk  Street/Sidewalk       10023.0
# 332  Posted Parking Sign Violation  Street/Sidewalk       11369.0
# 398  Posted Parking Sign Violation  Street/Sidewalk       10024.0
# 427                Blocked Hydrant  Street/Sidewalk       11419.0
#
#            incident_address  ... taxi_pick_up_location bridge_highway_name  \
# 121     68 WEST   85 STREET  ...                   NaN                 NaN
# 147      37 RIVERSIDE DRIVE  ...                   NaN                 NaN
# 332         22-45 95 STREET  ...                   NaN                 NaN
# 398    103 WEST   86 STREET  ...                   NaN                 NaN
# 427  120-14 ATLANTIC AVENUE  ...                   NaN                 NaN
#
#     bridge_highway_direction road_ramp bridge_highway_segment   latitude  \
# 121                      NaN       NaN                    NaN  40.785357
# 147                      NaN       NaN                    NaN  40.782988
# 332                      NaN       NaN                    NaN  40.769396
# 398                      NaN       NaN                    NaN  40.786582
# 427                      NaN       NaN                    NaN  40.694368
#
#      longitude                                        location  \
# 121 -73.971631   \n,  \n(40.7853573515737, -73.97163139082348)
# 147 -73.984260  \n,  \n(40.78298831826955, -73.98425988210684)
# 332 -73.875379   \n,  \n(40.76939593361693, -73.8753791197256)
# 398 -73.972378  \n,  \n(40.78658168399548, -73.97237837555912)
# 427 -73.826714  \n,  \n(40.69436813769891, -73.82671368709654)
#
#            duration day_of_week
# 121 0 days 00:01:54      Monday
# 147 0 days 00:04:55      Monday
# 332 0 days 00:03:38      Monday
# 398 0 days 00:03:04      Monday
# 427 0 days 00:01:34      Monday
#
# [5 rows x 43 columns]

# %% [markdown]
# loop

# %%
for index, row in dm_filtered.iterrows():
    duration = pd.to_timedelta(row['duration'])
    if duration.seconds < 60:
        duration = str(duration.seconds) + " seconds"
    else:
        minutes = duration.seconds // 60
        seconds = duration.seconds % 60
        duration = str(minutes) + " minutes and " + str(seconds) + " seconds"
    dm_filtered.at[index, 'duration'] = duration

# %%
filtered_dm.head()
# Out:
#      unique_key        created_date         closed_date agency  \
# 121    60948005 2024-04-22 22:32:09 2024-04-22 22:34:03   NYPD
# 147    60945232 2024-04-22 22:19:56 2024-04-22 22:24:51   NYPD
# 332    60946769 2024-04-22 19:08:44 2024-04-22 19:12:22   NYPD
# 398    60949323 2024-04-22 17:58:11 2024-04-22 18:01:15   NYPD
# 427    60950485 2024-04-22 17:34:46 2024-04-22 17:36:20   NYPD
#
#                          agency_name   complaint_type  \
# 121  New York City Police Department  Illegal Parking
# 147  New York City Police Department  Illegal Parking
# 332  New York City Police Department  Illegal Parking
# 398  New York City Police Department  Illegal Parking
# 427  New York City Police Department  Illegal Parking
#
#                         descriptor    location_type  incident_zip  \
# 121   Overnight Commercial Storage  Street/Sidewalk       10024.0
# 147              Blocked Crosswalk  Street/Sidewalk       10023.0
# 332  Posted Parking Sign Violation  Street/Sidewalk       11369.0
# 398  Posted Parking Sign Violation  Street/Sidewalk       10024.0
# 427                Blocked Hydrant  Street/Sidewalk       11419.0
#
#            incident_address  ... taxi_pick_up_location bridge_highway_name  \
# 121     68 WEST   85 STREET  ...                   NaN                 NaN
# 147      37 RIVERSIDE DRIVE  ...                   NaN                 NaN
# 332         22-45 95 STREET  ...                   NaN                 NaN
# 398    103 WEST   86 STREET  ...                   NaN                 NaN
# 427  120-14 ATLANTIC AVENUE  ...                   NaN                 NaN
#
#     bridge_highway_direction road_ramp bridge_highway_segment   latitude  \
# 121                      NaN       NaN                    NaN  40.785357
# 147                      NaN       NaN                    NaN  40.782988
# 332                      NaN       NaN                    NaN  40.769396
# 398                      NaN       NaN                    NaN  40.786582
# 427                      NaN       NaN                    NaN  40.694368
#
#      longitude                                        location  \
# 121 -73.971631   \n,  \n(40.7853573515737, -73.97163139082348)
# 147 -73.984260  \n,  \n(40.78298831826955, -73.98425988210684)
# 332 -73.875379   \n,  \n(40.76939593361693, -73.8753791197256)
# 398 -73.972378  \n,  \n(40.78658168399548, -73.97237837555912)
# 427 -73.826714  \n,  \n(40.69436813769891, -73.82671368709654)
#
#                      duration day_of_week
# 121  1 minutes and 54 seconds      Monday
# 147  4 minutes and 55 seconds      Monday
# 332  3 minutes and 38 seconds      Monday
# 398   3 minutes and 4 seconds      Monday
# 427  1 minutes and 34 seconds      Monday
#
# [5 rows x 43 columns]
