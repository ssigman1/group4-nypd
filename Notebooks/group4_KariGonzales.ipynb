# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd

# %% [markdown]
# ### IGNORED, DISMISSED: How the NYPD Neglects 311 Complaints about Driver Misconduct
#
# 1. Go to the New Data Portal: https://opendata.cityofnewyork.us/
# 2. Find each dataset. 311 requests and police precinct
# 3. Add a data notes section to your github readme. This should include information about the source of your data, where it came from, how often it is updated, and the period of data it contains (e.g. 2010-present or 2012 to 2019)
# 4. Lastly, test that this import works. This may take a while as the dataset is large.

# %%
# query NYC 311 for driver misconduct
# value list
complaint_types_dm = ('Blocked Bike Lane', 'Blocked Crosswalk', 'Blocked Hydrant', 'Blocked Sidewalk', 'Chronic Speeding', 'Chronic Stoplight Violation','Detached Trailer', 'Double Parked Blocking Traffic',
       'Double Parked Blocking Vehicle', 'Drag Racing',
       'Overnight Commercial Storage', 'Parking Permit Improper Use',
       'Posted Parking Sign Violation', 'Truck Route Violation',
       'Unauthorized Bus Layover', 'Abandoned Vehicle With License Plate' )
query = "https://data.cityofnewyork.us/resource/erm2-nwe9.csv?$query=" +  requests.utils.quote(f"SELECT * WHERE descriptor IN {complaint_types_dm}  LIMIT 3000000")
dm  = pd.read_csv(query)
# Out:
# <ipython-input-4-c56bcde3c9d2>:9: DtypeWarning: Columns (15,18,20,31,34,35,36,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   dm  = pd.read_csv(query)

# %%
dm.shape
# Out:
# (2200017, 41)

# %%
dm.head()
# Out:
#    unique_key             created_date closed_date agency  \
# 0    60926078  2024-04-21T01:43:06.000         NaN   NYPD
# 1    60929264  2024-04-21T01:41:43.000         NaN   NYPD
# 2    60931292  2024-04-21T01:40:04.000         NaN   NYPD
# 3    60933391  2024-04-21T01:39:26.000         NaN   NYPD
# 4    60929268  2024-04-21T01:37:05.000         NaN   NYPD
#
#                        agency_name   complaint_type       descriptor  \
# 0  New York City Police Department  Illegal Parking  Blocked Hydrant
# 1  New York City Police Department  Illegal Parking  Blocked Hydrant
# 2  New York City Police Department  Illegal Parking  Blocked Hydrant
# 3  New York City Police Department  Illegal Parking  Blocked Hydrant
# 4  New York City Police Department  Illegal Parking  Blocked Hydrant
#
#      location_type  incident_zip    incident_address  ... vehicle_type  \
# 0  Street/Sidewalk       10034.0  25 CUMMINGS STREET  ...          NaN
# 1  Street/Sidewalk       11370.0     32-01 76 STREET  ...          NaN
# 2  Street/Sidewalk       11385.0  1731 HARMAN STREET  ...          NaN
# 3  Street/Sidewalk       11385.0      72-29 65 PLACE  ...          NaN
# 4  Street/Sidewalk       11368.0     50-48 96 STREET  ...          NaN
#
#   taxi_company_borough taxi_pick_up_location bridge_highway_name  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
#
#   bridge_highway_direction road_ramp bridge_highway_segment   latitude  \
# 0                      NaN       NaN                    NaN  40.866699
# 1                      NaN       NaN                    NaN  40.756973
# 2                      NaN       NaN                    NaN  40.705165
# 3                      NaN       NaN                    NaN  40.700670
# 4                      NaN       NaN                    NaN  40.740791
#
#    longitude                                         location
# 0 -73.926486    \n,  \n(40.8666990148464, -73.92648618310697)
# 1 -73.891299   \n,  \n(40.75697287045501, -73.89129877560065)
# 2 -73.913619   \n,  \n(40.70516528260641, -73.91361876767822)
# 3 -73.888765   \n,  \n(40.70066997693598, -73.88876505286159)
# 4 -73.866523  \n,  \n(40.740791220984626, -73.86652283199825)
#
# [5 rows x 41 columns]

# %%
dm.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'location_type', 'incident_zip',
#        'incident_address', 'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'address_type',
#        'city', 'landmark', 'facility_type', 'status', 'due_date',
#        'resolution_description', 'resolution_action_updated_date',
#        'community_board', 'bbl', 'borough', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane', 'open_data_channel_type',
#        'park_facility_name', 'park_borough', 'vehicle_type',
#        'taxi_company_borough', 'taxi_pick_up_location', 'bridge_highway_name',
#        'bridge_highway_direction', 'road_ramp', 'bridge_highway_segment',
#        'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
# get police precint data

police = gpd.read_file('https://data.cityofnewyork.us/api/geospatial/78dh-3ptz?method=export&format=GeoJSON')

# %%
police.columns
# Out:
# Index(['precinct', 'shape_area', 'shape_leng', 'geometry'], dtype='object')

# %%
dm.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'location_type', 'incident_zip',
#        'incident_address', 'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'address_type',
#        'city', 'landmark', 'facility_type', 'status', 'due_date',
#        'resolution_description', 'resolution_action_updated_date',
#        'community_board', 'bbl', 'borough', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane', 'open_data_channel_type',
#        'park_facility_name', 'park_borough', 'vehicle_type',
#        'taxi_company_borough', 'taxi_pick_up_location', 'bridge_highway_name',
#        'bridge_highway_direction', 'road_ramp', 'bridge_highway_segment',
#        'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
dm['created_date'] = pd.to_datetime(dm['created_date'])
dm['closed_date'] = pd.to_datetime(dm['closed_date'])
dm['duration'] = dm['closed_date'] - dm['created_date']

filtered_dm = dm[dm['duration'] <= pd.Timedelta(minutes=5)]

# %%
filtered_dm.sample(8)
# Out:
#         unique_key        created_date         closed_date agency  \
# 498763    56840948 2023-02-18 22:15:02 2023-02-18 22:18:56   NYPD
# 951868    52587486 2021-11-21 22:50:54 2021-11-21 22:54:52   NYPD
# 930586    52801018 2021-12-14 20:55:00 2021-12-14 20:58:09   NYPD
# 417156    57502282 2023-05-04 13:24:04 2023-05-04 13:24:41   NYPD
# 214066    59228534 2023-10-25 07:49:27 2023-10-25 07:52:18   NYPD
# 493565    56886138 2023-02-24 09:43:01 2023-02-24 09:44:44   NYPD
# 128342    59931157 2024-01-04 14:48:03 2024-01-04 14:52:34   NYPD
# 81618     60306021 2024-02-12 14:04:15 2024-02-12 14:07:03   NYPD
#
#                             agency_name   complaint_type  \
# 498763  New York City Police Department  Illegal Parking
# 951868  New York City Police Department  Illegal Parking
# 930586  New York City Police Department  Illegal Parking
# 417156  New York City Police Department  Illegal Parking
# 214066  New York City Police Department  Illegal Parking
# 493565  New York City Police Department  Illegal Parking
# 128342  New York City Police Department  Illegal Parking
# 81618   New York City Police Department  Illegal Parking
#
#                            descriptor    location_type  incident_zip  \
# 498763  Posted Parking Sign Violation  Street/Sidewalk       10016.0
# 951868  Posted Parking Sign Violation  Street/Sidewalk       10027.0
# 930586  Posted Parking Sign Violation  Street/Sidewalk       11367.0
# 417156                Blocked Hydrant  Street/Sidewalk       11222.0
# 214066  Posted Parking Sign Violation  Street/Sidewalk       11231.0
# 493565              Blocked Bike Lane  Street/Sidewalk       10457.0
# 128342  Posted Parking Sign Violation  Street/Sidewalk       11233.0
# 81618     Parking Permit Improper Use  Street/Sidewalk       10012.0
#
#                 incident_address  ... taxi_company_borough  \
# 498763       38 EAST   29 STREET  ...                  NaN
# 951868     9 MT MORRIS PARK WEST  ...                  NaN
# 930586        72-11 VLEIGH PLACE  ...                  NaN
# 417156  305 MCGUINNESS BOULEVARD  ...                  NaN
# 214066           158 KANE STREET  ...                  NaN
# 493565   213 EAST TREMONT AVENUE  ...                  NaN
# 128342         692 HALSEY STREET  ...                  NaN
# 81618       567 LA GUARDIA PLACE  ...                  NaN
#
#        taxi_pick_up_location bridge_highway_name bridge_highway_direction  \
# 498763                   NaN                 NaN                      NaN
# 951868                   NaN                 NaN                      NaN
# 930586                   NaN                 NaN                      NaN
# 417156                   NaN                 NaN                      NaN
# 214066                   NaN                 NaN                      NaN
# 493565                   NaN                 NaN                      NaN
# 128342                   NaN                 NaN                      NaN
# 81618                    NaN                 NaN                      NaN
#
#        road_ramp bridge_highway_segment   latitude  longitude  \
# 498763       NaN                    NaN  40.744436 -73.984807
# 951868       NaN                    NaN  40.804424 -73.945768
# 930586       NaN                    NaN  40.726520 -73.821128
# 417156       NaN                    NaN  40.732676 -73.952040
# 214066       NaN                    NaN  40.686591 -73.997883
# 493565       NaN                    NaN  40.849071 -73.905137
# 128342       NaN                    NaN  40.684563 -73.925782
# 81618        NaN                    NaN  40.729450 -73.997756
#
#                                               location        duration
# 498763  \n,  \n(40.74443574284639, -73.98480671020883) 0 days 00:03:54
# 951868  \n,  \n(40.80442395416177, -73.94576777962213) 0 days 00:03:58
# 930586  \n,  \n(40.72652004197567, -73.82112804354149) 0 days 00:03:09
# 417156  \n,  \n(40.73267647360861, -73.95203953010382) 0 days 00:00:37
# 214066  \n,  \n(40.68659089481524, -73.99788343837996) 0 days 00:02:51
# 493565   \n,  \n(40.849070685610705, -73.905136529099) 0 days 00:01:43
# 128342  \n,  \n(40.68456329667932, -73.92578196785284) 0 days 00:04:31
# 81618    \n,  \n(40.7294503731134, -73.99775579547246) 0 days 00:02:48
#
# [8 rows x 42 columns]

# %% [markdown]
# Day of week

# %%
data = filtered_dm['created_date'].value_counts()

# %%
def get_day_of_week(date_str):
    date_obj = pd.to_datetime(date_str)
    return date_obj.day_name()

# %%
filtered_dm.loc[:,'day_of_week'] = filtered_dm['created_date'].apply(get_day_of_week)

# %%
day_counts = filtered_dm.groupby('day_of_week').size().reset_index(name='day_count')

# %%
day_of_week = day_counts['day_count'].mean()

# %%
day_counts['day_of_week'] = day_counts['day_count'] > day_of_week

# %%
combined_df = pd.concat([filtered_dm, day_counts[['day_of_week']]], axis=1)

# %%
filtered_dm.sample()
# Out:
#         unique_key        created_date         closed_date agency  \
# 911246    53000179 2022-01-08 23:00:31 2022-01-08 23:05:06   NYPD
#
#                             agency_name   complaint_type  \
# 911246  New York City Police Department  Illegal Parking
#
#                             descriptor    location_type  incident_zip  \
# 911246  Double Parked Blocking Vehicle  Street/Sidewalk       11210.0
#
#             incident_address  ... bridge_highway_name  \
# 911246  1796 BROOKLYN AVENUE  ...                 NaN
#
#        bridge_highway_direction road_ramp bridge_highway_segment   latitude  \
# 911246                      NaN       NaN                    NaN  40.629034
#
#        longitude                                        location  \
# 911246 -73.94145  \n,  \n(40.62903443151011, -73.94145026152664)
#
#               duration Frequency day_of_week
# 911246 0 days 00:04:35       NaN    Saturday
#
# [1 rows x 44 columns]
